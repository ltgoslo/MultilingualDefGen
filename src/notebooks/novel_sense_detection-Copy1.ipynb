# %%
import csv
from itertools import combinations
import pandas as pd
from sklearn.model_selection import train_test_split
import evaluate
from sentence_transformers import CrossEncoder, SentenceTransformer
import numpy as np
from sklearn.cluster import AgglomerativeClustering

# %%
rouge = evaluate.load("rouge")
# Out:
# WARNING:evaluate.loading:Using the latest cached version of the module from /home/laks/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--rouge/b01e0accf3bd6dd24839b769a5fda24e14995071570870922c71970b3a6ed886 (last modified on Mon Dec 25 18:07:17 2023) since it couldn't be found locally at evaluate-metric--rouge, or remotely on the Hugging Face Hub.

# %%
dev = pd.read_csv('ru-dev.csv', sep='\t', quoting=csv.QUOTE_NONE)

# %%
def create_dataset(dev, lang):
    to_return = {'gloss':[], 'Generated_Definition':[], 'score':[]}
    for word in dev.word.unique():
        this_word = dev[dev.word == word]
        for sense in this_word.sense_id.unique():
            this_sense = this_word[this_word.sense_id==sense]

            to_predict = list(this_sense[['gloss', 'Generated_Definition']].dropna().itertuples(index=False, name=None))
            if to_predict:
                sims = model.predict(to_predict)
                most_similar = to_predict[np.argmax(sims)]
                to_return['gloss'].append(most_similar[0])
                to_return['Generated_Definition'].append(most_similar[1])
                to_return['score'].append(1)
            
            other_sense = this_word[this_word.sense_id!=sense].Generated_Definition.dropna()
            for other, this in zip(other_sense, this_sense):
                to_return['gloss'].append(this)
                to_return['Generated_Definition'].append(other)
                to_return['score'].append(0)
    to_return = pd.DataFrame(to_return)
    to_return['lang'] = [lang for i in range(to_return.shape[0])]
    return to_return

# %%
dev.head()
# Out:
#    Unnamed: 0  usage_id       word        orth               sense_id  \
# 0           0  dev_ru_0  могильник  могильникъ  mogil'nik_UYTE5-B076I
# 1           1  dev_ru_1  могильник  могильникъ  mogil'nik_C3GhETZc5Vs
# 2           2  dev_ru_2  могильник  могильникъ  mogil'nik_KNs3eVn3pFY
# 3           3  dev_ru_3  могильник  могильникъ  mogil'nik_ahboIs9hMMk
# 4           4  dev_ru_4  могильник  могильникъ  mogil'nik_ahboIs9hMMk
#
#                                                gloss  \
# 0  вят. слово из Вятской губернии арх. слово из А...
# 1  ярс. слово из Ярославской губернии крупный коч...
# 2  арх. слово из Архангельской губернии походный ...
# 3   орнитол. хищная птица рода крупных степных орлов
# 4   орнитол. хищная птица рода крупных степных орлов
#
#                                              example  indices_target_token  \
# 0                                  могилки, кладбище                   NaN
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3  Орёл изображает реку Халзан, его голова ― скал...                   NaN
# 4                                     Орел могильник                   NaN
#
#   date period                                      Real_Contexts  \
# 0  old    old             могилки, кладбище Что такое могильник?
# 1  old    old                                                NaN
# 2  old    old                                                NaN
# 3  new    new  Орёл изображает реку Халзан, его голова ― скал...
# 4  old    old                Орел могильник Что такое могильник?
#
#                    Generated_Definition
# 0            кладбище, могильная камера
# 1                                   NaN
# 2                                   NaN
# 3  арх. слово из Архангельской губернии
# 4  арх. слово из Архангельской губернии

# %%
model = CrossEncoder("BAAI/bge-reranker-v2-m3")

# %%
ru = create_dataset(dev, 'ru')

# %%
ru.shape
# Out:
# (8369, 4)

# %%
ru = ru.drop_duplicates()
ru.shape
# Out:
# (4209, 4)

# %%
fin = pd.read_csv('../dev_set/mt0-xl/ax_fi_2.tsv.gz', sep='\t', quoting=csv.QUOTE_NONE, compression='gzip')
fi = create_dataset(fin, 'fi')
# Out:
# (3356, 3)

# %%
dataset = pd.concat((ru, fi))

# %%
train, test = train_test_split(ru, shuffle=True, stratify=ru['score'], random_state=42)

# %%
import torch
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from Levenshtein import distance, ratio
import swifter

# %%
to_predict = list(test[['gloss', 'Generated_Definition']].itertuples(index=False, name=None))
sims_test = model.predict(to_predict)
test['sims'] = sims_test
# test['lev'] = test.apply(lambda x: ratio(x.gloss, x.Generated_Definition), axis=1)
# test.to_csv('test_sims.csv')

# %%
train
# Out:
#                                                   gloss  \
# 629                                сыпаться через край;
# 1559             свойственный бане, характерный для неё
# 1088  событие, лишившее кого-то собственности или до...
# 106       перен. обеспечивающий достижение цели; верный
# 262                                         мужское имя
# ...                                                 ...
# 1248                                        город Пруса
# 1713  явление действительности, факт, обстоятельство...
# 1253  жарг. узнать у кого-либо что-либо, получить ка...
# 1361  перен. освободить место, проход куда-либо, зас...
# 1621                перен. любое стремительное движение
#
#                                    Generated_Definition  score lang      sims
# 629   пересыпая, засыпая более чем столько, чтобы не...      0   ru  0.208872
# 1559  связанный, соотносящийся по значению с существ...      1   ru  0.192625
# 1088  перен. потера чего-либо, лишение кого-либо, че...      1   ru  0.742397
# 106   обладающий крепостью, способный выдерживаться ...      0   ru  0.012446
# 262   устар. и разг. кличка, используемая для иденти...      0   ru  0.001389
# ...                                                 ...    ...  ...       ...
# 1248  устар. и истор. род племени в северных областя...      0   ru  0.001371
# 1713  действие по значению гл. вещать; то, что имеет...      0   ru  0.065916
# 1253  перен., разг. улучшить качество, уровень чего-...      1   ru  0.005224
# 1361           очищая, удалять загрязнения, грязь, пыль      0   ru  0.003262
# 1621  перен., разг. движение с большим темпом, быстр...      1   ru  0.991683
#
# [2690 rows x 5 columns]

# %%
test
# Out:
#                                                   gloss  \
# 886   разг. наскоро, слегка или в отдельных местах в...
# 1399  школа (вообще место, откуда разносится наука, ...
# 818          выпустить, испустить, извергнуть, источить
# 1001                                     способ рыбалки
# 705   трансп. специально оборудованная на маршруте т...
# ...                                                 ...
# 1172  действие по глаголу проклинать. Наложить на ко...
# 840   из пуха или с пухом; на пуху; валеная из звери...
# 1067  перен., разг. приезжать, приплывать куда-либо ...
# 1669  имеющий бороду или сильно заросший бородой (о ...
# 426   влгд. слово из Вологодской губернии полоса мол...
#
#                                    Generated_Definition  score lang
# 886                  поднять, помочь чему-либо помыться      1   ru
# 1399  перен., разг. источник, рассадная площадь для ...      1   ru
# 818   разг., обычно с доп. вынудять прекратиться, пр...      1   ru
# 1001                       устар. и рег. набор, сборище      0   ru
# 705   перен., разг. основание, на котором располагаю...      0   ru
# ...                                                 ...    ...  ...
# 1172                                   устар. проклятье      0   ru
# 840                                разг. содержащий пух      1   ru
# 1067  идя, покидать [ I ] какое-либо место, то есть ...      0   ru
# 1669                       перен., разг. имеющий борода      1   ru
# 426   ленты, расположенные по всей длине какого-либо...      0   ru
#
# [897 rows x 4 columns]

# %%
def predict_sims(ds):
    to_predict = list(ds[['gloss', 'Generated_Definition']].itertuples(index=False, name=None))
    sims = model.predict(to_predict)
    ds['sims'] = sims
    return ds

# %%
ru
# Out:
#                                                   gloss  \
# 0     вят. слово из Вятской губернии арх. слово из А...
# 1     ярс. слово из Ярославской губернии крупный коч...
# 2     арх. слово из Архангельской губернии походный ...
# 3      орнитол. хищная птица рода крупных степных орлов
# 4      орнитол. хищная птица рода крупных степных орлов
# ...                                                 ...
# 2021  перен. разг. страстное увлечение, возбуждение;...
# 2022  перен. разг. страстное увлечение, возбуждение;...
# 2023  перен. разг. страстное увлечение, возбуждение;...
# 2024  перен. напряженная работа, требующая немедленн...
# 2025  перен. напряженная работа, требующая немедленн...
#
#                                   Generated_Definition  score lang
# 0                                      охотник, убийца      0   ru
# 1                                             кладбище      0   ru
# 2                                             кладбище      0   ru
# 3                                             кладбище      0   ru
# 4                                курганное захоронение      0   ru
# ...                                                ...    ...  ...
# 2021            сильное, быстрое повышенное воспаление      1   ru
# 2022                       сильное, неприятное чувство      1   ru
# 2023                творческая горячность, страстность      1   ru
# 2024  сильное эмоциональное состояние, часто внезапное      1   ru
# 2025                    сильное волнение, беспокойство      1   ru
#
# [3541 rows x 4 columns]

# %%
# dev = pd.read_csv('ru-dev-aya.csv', sep='\t', quoting=csv.QUOTE_NONE)
# ru = create_dataset(dev, 'ru')
# train, test = train_test_split(ru, shuffle=True, stratify=ru['score'], random_state=42)
train = predict_sims(train)
test = predict_sims(test)
clf = tree.DecisionTreeClassifier()

clf = clf.fit(train[['sims']], train['score'])
predictions = clf.predict(test[[ 'sims']])
print(classification_report(test['score'], predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       832
#            1       0.63      0.63      0.63       221
#
#     accuracy                           0.84      1053
#    macro avg       0.77      0.77      0.77      1053
# weighted avg       0.84      0.84      0.84      1053

# %%
rouge = evaluate.load("rouge")
# Out:
# WARNING:evaluate.loading:Using the latest cached version of the module from /home/laks/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--rouge/b01e0accf3bd6dd24839b769a5fda24e14995071570870922c71970b3a6ed886 (last modified on Mon Dec 25 18:07:17 2023) since it couldn't be found locally at evaluate-metric--rouge, or remotely on the Hugging Face Hub.

# %%
def calc_rouge(ds):
    ds['rouge'] = ds.apply(lambda x: rouge.compute(
    predictions=[x.gloss+'\n'], references=[x.Generated_Definition+'\n'], tokenizer=lambda y: y.split()
), axis=1)
    ds['rouge1'] = [x['rouge1'] if isinstance(x, dict) else 0 for x in ds['rouge']]
    ds['rouge2'] = [x['rouge2'] if isinstance(x, dict) else 0 for x in ds['rouge']]
    ds['rougeL'] = [x['rougeL'] if isinstance(x, dict) else 0 for x in ds['rouge']]
    ds['rougeLsum'] = [x['rougeLsum'] if isinstance(x, dict) else 0 for x in ds['rouge']]
    return ds

# %%
clf =LogisticRegression()

clf = clf.fit(train[['sims']], train['score'])
predictions = clf.predict(test[[ 'sims']])
print(classification_report(test['score'], predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       832
#            1       0.91      0.50      0.64       221
#
#     accuracy                           0.88      1053
#    macro avg       0.89      0.74      0.79      1053
# weighted avg       0.89      0.88      0.87      1053

# %%
train = predict_sims(train)
train = calc_rouge(train)
test = calc_rouge(test)

# %%
train.head()
# Out:
#            gloss                               Generated_Definition  score  \
# 8090  Unnamed: 0  свойство по значению прилагатника гладкий; лаб...      0
# 5101        date  действие по значению гл. прогонять; обыск, вые...      0
# 7125       gloss  перен., бран. скверный, низменный, ничтожный ч...      0
# 5787        orth       разг. удалять откуда-либо, снять с чего-либо      0
# 6484        orth  часть автомобиля, предназначенная для хранения...      0
#
#      lang      sims                                              rouge  \
# 8090   ru  0.000032  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...
# 5101   ru  0.000024  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...
# 7125   ru  0.018614  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...
# 5787   ru  0.025723  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...
# 6484   ru  0.002535  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...
#
#       rouge1  rouge2  rougeL  rougeLsum
# 8090     0.0     0.0     0.0        0.0
# 5101     0.0     0.0     0.0        0.0
# 7125     0.0     0.0     0.0        0.0
# 5787     0.0     0.0     0.0        0.0
# 6484     0.0     0.0     0.0        0.0

# %%
test.head()
# Out:
#                                        gloss  \
# 6479                           Real_Contexts
# 7515                                usage_id
# 7412                              Unnamed: 0
# 7736                    indices_target_token
# 5050  действие по значению глагола прогонять
#
#                                    Generated_Definition  score lang  \
# 6479  базовая, стояночная площадь для какого-либо ав...      0   ru
# 7515                       разг., устар. бедная женщина      0   ru
# 7412  перен., разг. жить, существовать в процессе пр...      0   ru
# 7736  период в истории человечества, определённый ка...      0   ru
# 5050               действие по значению гл. гонять; бег      1   ru
#
#                                                   rouge    rouge1    rouge2  \
# 6479  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...  0.000000  0.000000
# 7515  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...  0.000000  0.000000
# 7412  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...  0.000000  0.000000
# 7736  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, ...  0.000000  0.000000
# 5050  {'rouge1': 0.5454545454545454, 'rouge2': 0.444...  0.545455  0.444444
#
#         rougeL  rougeLsum
# 6479  0.000000   0.000000
# 7515  0.000000   0.000000
# 7412  0.000000   0.000000
# 7736  0.000000   0.000000
# 5050  0.545455   0.545455

# %%
clf =LogisticRegression()

clf = clf.fit(train[['sims', 'rouge1', 'rouge2', 'rougeL', 'rougeLsum']], train['score'])
#test = predict_sims(test)

predictions = clf.predict(test[[ 'sims', 'rouge1', 'rouge2', 'rougeL', 'rougeLsum']])
print(classification_report(test['score'], predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94       832
#            1       0.92      0.56      0.69       221
#
#     accuracy                           0.90      1053
#    macro avg       0.91      0.77      0.82      1053
# weighted avg       0.90      0.90      0.89      1053

# %%
encoder =SentenceTransformer('sentence-transformers/distiluse-base-multilingual-cased-v1')

# %%
train.columns
# Out:
# Index(['gloss', 'Generated_Definition', 'score', 'lang', 'sims', 'rouge',
#        'rouge1', 'rouge2', 'rougeL', 'rougeLsum'],
#       dtype='object')

# %%
dev_new = dev[dev.period=='new']
dev_new.head()
# Out:
#     Unnamed: 0   usage_id       word        orth               sense_id  \
# 3            3   dev_ru_3  могильник  могильникъ  mogil'nik_ahboIs9hMMk
# 7            7   dev_ru_7  могильник  могильникъ  mogil'nik_FciH4mIkAEU
# 8            8   dev_ru_8  могильник  могильникъ  mogil'nik_FciH4mIkAEU
# 9            9   dev_ru_9  могильник  могильникъ  mogil'nik_W-DBS9zwZiI
# 10          10  dev_ru_10  могильник  могильникъ  mogil'nik_W-DBS9zwZiI
#
#                                                 gloss  \
# 3    орнитол. хищная птица рода крупных степных орлов
# 7   археол. в древности — комплекс многих погребен...
# 8   археол. в древности — комплекс многих погребен...
# 9   спец. место захоронения радиоактивных отходов;...
# 10  спец. место захоронения радиоактивных отходов;...
#
#                                               example  indices_target_token  \
# 3   Орёл изображает реку Халзан, его голова ― скал...                   NaN
# 7   В экспозиции представлен инвентарь из реликтов...                   NaN
# 8   Близ Барбашиной поляны отрыт мордовский могиль...                   NaN
# 9   О строительстве могильника для захоронения рад...                   NaN
# 10  Якобы тут, возле Черниховки, находится радиоак...                   NaN
#
#    date period                                      Real_Contexts  \
# 3   new    new  Орёл изображает реку Халзан, его голова ― скал...
# 7   new    new  В экспозиции представлен инвентарь из реликтов...
# 8   new    new  Близ Барбашиной поляны отрыт мордовский могиль...
# 9   new    new  О строительстве могильника для захоронения рад...
# 10  new    new  Якобы тут, возле Черниховки, находится радиоак...
#
#                             Generated_Definition
# 3           арх. слово из Архангельской губернии
# 7           арх. слово из Архангельской губернии
# 8           арх. слово из Архангельской губернии
# 9           арх. слово из Архангельской губернии
# 10  перен., книжн. кладбище, могильная местность

# %%
from sklearn.metrics import adjusted_rand_score
from collections import Counter
from leven import levenshtein

# %%
def find_merges(df):
    targ_words = df.word.unique()

    # Finding definitions similar to the most frequent one (paraphrases) for each targ_word:
    mappings = {targ_word: {} for targ_word in targ_words}

    for targ_word in targ_words:
        definitions = Counter(df[df.word == targ_word].Generated_Definition.dropna()).most_common()
        if definitions:
        # definitions = sorted(definitions)  # can be commented to out to start from most frequent
            sim_cache = {}
            def2compare = None
            for nr, source in enumerate(definitions):
                cand = source[0]
                if len(cand.split()) >= 4 and cand not in mappings[targ_word]:
                    def2compare = cand
                    mapped = 0
                    for definition in definitions:
                        definition_text = definition[0]
                        if definition_text != def2compare and \
                                definition_text not in mappings[targ_word]:
                            if (definition_text, def2compare) in sim_cache:
                                distance = sim_cache[(definition_text, def2compare)]
                            else:
                                distance = levenshtein(definition_text, def2compare)
                                sim_cache[(definition_text, def2compare)] = distance
                                sim_cache[(def2compare, definition_text)] = distance
                            if distance < 10:
                                mappings[targ_word][definition_text] = def2compare
                                mapped += 1

                if def2compare:
                    break

    return mappings, targ_words

# %%
mappings, targ_words = find_merges(train_new)

# %%
mappings
# Out:
# {'могильник': {},
#  'монитор': {},
#  'мороз': {'устар. холодная погодa': 'устар. холодное время года'},
#  'мундштук': {'часть трубки, соединяющая рот с остальной частью папиросы': 'часть трубки, соединяющая рот с остальной частью трубки'},
#  'муж': {},
#  'мужчина': {'лингв., разг. человек, принадлежающий мужчине [ 1 ]': 'лингв., устар. человек, принадлежающий к мужчине [ 1 ]'},
#  'мурман': {},
#  'мясо': {},
#  'нос': {},
#  'нагулять': {},
#  'надёжный': {'обладающий высоким уровнем надежности, стойкости': 'обладающий высоким уровнем надежности, стабильности'},
#  'надой': {},
#  'назначить': {},
#  'наиграть': {},
#  'наносить': {},
#  'наново': {},
#  'наносный': {},
#  'нараспашку': {},
#  'номер': {},
#  'нора': {},
#  'нота': {},
#  'набрать': {},
#  'наверх': {},
#  'находить': {},
#  'натирать': {},
#  'натурный': {'настоящий, истиный, действующий на деле': 'настоящий, живой, действующий на деле'},
#  'нейтральный': {},
#  'неподвижный': {},
#  'нива': {},
#  'низменный': {},
#  'ник': {},
#  'обводить': {'обрисовываться, рисовать по контуру чего-либо': 'обрисовываться, рисоваться вокруг чего-либо'},
#  'облако': {},
#  'областной': {},
#  'обмывать': {'погружать в воду или другую жидкость для мытья, обработки и т. п.': 'погружать в воду или другую жидкость для мытья, обработки',
#   'разг. погружать в воду или другую жидкость для мытья, обработки': 'погружать в воду или другую жидкость для мытья, обработки'},
#  'обрывать': {},
#  'обух': {},
#  'отступать': {'перен., разг. уходить в сторону, ступая': 'перен., разг. уходить в сторону, удаляться'},
#  'отдать': {},
#  'отрубить': {},
#  'отчаянный': {},
#  'оговорить': {},
#  'округлить': {'перен. сделать округлым; облегчить, уменьшать в объёме': 'перен. сделать округлым; подтянуть, уменьшать в объёме'},
#  'общий': {'имеющий отношение к кому-либо, чему-либо общему, существующий для всех': 'имеющий отношение к кому-либо, чему-либо общему, существующий вместе'},
#  'опадать': {},
#  'оптика': {},
#  'опутать': {},
#  'лента': {},
#  'летун': {},
#  'лещ': {'зоол. рыба семейства кошкообразных': 'зоол. рыба семейства осетровых',
#   'рыба из семейства осетровых': 'зоол. рыба семейства осетровых'},
#  'лизать': {},
#  'линия': {},
#  'лист': {},
#  'литовка': {},
#  'логовище': {},
#  'ложе': {},
#  'лох': {},
#  'луковица': {},
#  'падла': {'перен., бран. низменный, ничтожный человек': 'перен., бран. скверный, низменный человек'},
#  'паз': {},
#  'папка': {},
#  'парафраз': {},
#  'парк': {},
#  'паровоз': {'тяжёлый, большой паромщик': 'тяжёлый, большой паромный вагон'},
#  'партия': {},
#  'пачка': {},
#  'перевёртыш': {},
#  'передок': {},
#  'передовой': {},
#  'пересыпать': {},
#  'перетереть': {},
#  'перо': {},
#  'петрушка': {},
#  'пионер': {},
#  'платформа': {},
#  'плотный': {},
#  'поболтать': {},
#  'побывать': {},
#  'погасить': {},
#  'пул': {},
#  'пульс': {},
#  'пустить': {},
#  'путь': {},
#  'пуховый': {'разг. содержащий пух': 'разг. содержащий много пуха'},
#  'пятак': {},
#  'пятерик': {},
#  'подвиг': {},
#  'поддувало': {},
#  'подмыть': {},
#  'подпускать': {},
#  'подтяжка': {},
#  'поймать': {},
#  'покрытие': {},
#  'положить': {},
#  'полёт': {'действие по значению гл. летать; передвижение в воздухе': 'действие по значению гл. летать; перемещение в воздухе'},
#  'полный': {'перен. полностью исполненный, сытый': 'перен. полностью исполненный, законченный'},
#  'полотнище': {'устар. часть одежды, покрывающая спину человека': 'часть одежды, покрывающая спину человека'},
#  'поносить': {},
#  'порвать': {},
#  'порочный': {},
#  'посадка': {},
#  'постав': {},
#  'потеря': {'перен. утрата чего-либо, лишение кого-либо, чего-либо': 'перен., разг. утрата чего-либо, лишение кого-либо, чего-либо'},
#  'потребность': {},
#  'похерить': {},
#  'почистить': {},
#  'привод': {'действие по значению гл. привести; подвод': 'действие по значению гл. приводит; подвод'},
#  'прижимать': {},
#  'приходить': {},
#  'пропорциональный': {},
#  'пришить': {},
#  'пробивка': {},
#  'пробить': {},
#  'проводка': {},
#  'провизия': {},
#  'прогон': {},
#  'прозябать': {},
#  'производитель': {},
#  'произвольный': {},
#  'прокачать': {},
#  'проклятие': {},
#  'промышленный': {},
#  'пронзить': {},
#  'пронизать': {},
#  'пропащий': {'перен., разг. ничем не примечательный; бесценный': 'перен., разг. ничем не примечательный; безнадёжный'},
#  'проработать': {'провести некоторое время, работу над чем-либо': 'перен. провести некоторое время, работу над чем-либо'},
#  'проскочить': {'перен., разг. пропустить что-либо, не заметив': 'перен., разг. пропустить что-либо, не заметить'},
#  'просо': {},
#  'простирать': {},
#  'профиль': {},
#  'прус': {},
#  'разбить': {},
#  'развалить': {},
#  'развод': {},
#  'рана': {},
#  'расклеить': {},
#  'рассадник': {},
#  'распускать': {'разг. выпускать, пуская в сторону': 'разг. выпускать, пуская в расход',
#   'разг. выпускать, пуская из себя': 'разг. выпускать, пуская в расход'},
#  'раствор': {},
#  'расчистить': {},
#  'реакция': {},
#  'регулярный': {'такой, который происходит или проводится регулярно': 'такой, который происходит или делается регулярно'},
#  'ряд': {},
#  'ровно': {},
#  'роза': {},
#  'роман': {},
#  'роспуск': {},
#  'ангажировать': {'перен. привлечь к какому-либо делу, заниматься чем-либо': 'перен. привлечь к какому-либо делу, связать с чем-либо'},
#  'аренда': {},
#  'арт': {},
#  'афера': {'хитрость, подлый трюк, обман': 'разг. хитрость, подлый трюк, обман'},
#  'баня': {},
#  'банный': {},
#  'база': {},
#  'баклага': {},
#  'балансировать': {},
#  'болячка': {},
#  'барсук': {},
#  'батист': {},
#  'бег': {},
#  'безвременье': {},
#  'бич': {'перен., бран. позор, бесчестность': 'устар., разг. позор, бесчестность'},
#  'близкий': {},
#  'борзой': {},
#  'бородатый': {},
#  'бросать': {'перен., разг. бросить что-либо вообще': 'перен., разг. бросить что-либо вразброс'},
#  'брожение': {},
#  'бригада': {},
#  'бронь': {},
#  'брус': {},
#  'брызгать': {'перен. издавать брызги, хлопки': 'перен. издавать брызги, вздохи',
#   'перен. издавать брызги, вздутия': 'перен. издавать брызги, вздохи'},
#  'буза': {},
#  'былина': {},
#  'водник': {},
#  'водный': {},
#  'вал': {},
#  'вальяжный': {},
#  'вариться': {},
#  'векша': {},
#  'величаться': {},
#  'вертун': {},
#  'ветошь': {},
#  'вещь': {'мн. ч. то, что принадлежит кому-либо, чему-либо': 'ед. ч. то, что принадлежит кому-либо, чему-либо'},
#  'внимание': {},
#  'воздух': {},
#  'воля': {},
#  'время': {},
#  'вуаль': {},
#  'вывалить': {},
#  'выгрузить': {},
#  'выработать': {},
#  'гармонист': {},
#  'гик': {},
#  'голова': {},
#  'гладкость': {},
#  'глотать': {},
#  'глубина': {},
#  'говно': {},
#  'голубой': {'перен. цвет вечернего ясного неба, цвет между голубым и фиолетовым': 'имеющий цвет вечернего ясного неба, цвет между голубым и фиолетовым'},
#  'горбатый': {},
#  'горячка': {}}

# %%
targ_words
# Out:
# array(['могильник', 'монитор', 'мороз', 'мундштук', 'муж', 'мужчина',
#        'мурман', 'мясо', 'нос', 'нагулять', 'надёжный', 'надой',
#        'назначить', 'наиграть', 'наносить', 'наново', 'наносный',
#        'нараспашку', 'номер', 'нора', 'нота', 'набрать', 'наверх',
#        'находить', 'натирать', 'натурный', 'нейтральный', 'неподвижный',
#        'нива', 'низменный', 'ник', 'обводить', 'облако', 'областной',
#        'обмывать', 'обрывать', 'обух', 'отступать', 'отдать', 'отрубить',
#        'отчаянный', 'оговорить', 'округлить', 'общий', 'опадать',
#        'оптика', 'опутать', 'лента', 'летун', 'лещ', 'лизать', 'линия',
#        'лист', 'литовка', 'логовище', 'ложе', 'лох', 'луковица', 'падла',
#        'паз', 'папка', 'парафраз', 'парк', 'паровоз', 'партия', 'пачка',
#        'перевёртыш', 'передок', 'передовой', 'пересыпать', 'перетереть',
#        'перо', 'петрушка', 'пионер', 'платформа', 'плотный', 'поболтать',
#        'побывать', 'погасить', 'пул', 'пульс', 'пустить', 'путь',
#        'пуховый', 'пятак', 'пятерик', 'подвиг', 'поддувало', 'подмыть',
#        'подпускать', 'подтяжка', 'поймать', 'покрытие', 'положить',
#        'полёт', 'полный', 'полотнище', 'поносить', 'порвать', 'порочный',
#        'посадка', 'постав', 'потеря', 'потребность', 'похерить',
#        'почистить', 'привод', 'прижимать', 'приходить',
#        'пропорциональный', 'пришить', 'пробивка', 'пробить', 'проводка',
#        'провизия', 'прогон', 'прозябать', 'производитель', 'произвольный',
#        'прокачать', 'проклятие', 'промышленный', 'пронзить', 'пронизать',
#        'пропащий', 'проработать', 'проскочить', 'просо', 'простирать',
#        'профиль', 'прус', 'разбить', 'развалить', 'развод', 'рана',
#        'расклеить', 'рассадник', 'распускать', 'раствор', 'расчистить',
#        'реакция', 'регулярный', 'ряд', 'ровно', 'роза', 'роман',
#        'роспуск', 'ангажировать', 'аренда', 'арт', 'афера', 'баня',
#        'банный', 'база', 'баклага', 'балансировать', 'болячка', 'барсук',
#        'батист', 'бег', 'безвременье', 'бич', 'близкий', 'борзой',
#        'бородатый', 'бросать', 'брожение', 'бригада', 'бронь', 'брус',
#        'брызгать', 'буза', 'былина', 'водник', 'водный', 'вал',
#        'вальяжный', 'вариться', 'векша', 'величаться', 'вертун', 'ветошь',
#        'вещь', 'внимание', 'воздух', 'воля', 'время', 'вуаль', 'вывалить',
#        'выгрузить', 'выработать', 'гармонист', 'гик', 'голова',
#        'гладкость', 'глотать', 'глубина', 'говно', 'голубой', 'горбатый',
#        'горячка'], dtype=object)

# %%
new_defs = []
for word in train_new.word.unique():
    word_map = mappings[word]
    this_word = train_new[train_new.word==word]
    for defi in this_word.Generated_Definition:
        new = word_map.get(defi, defi)
        new_defs.append(defi)

# %%
dev = pd.read_csv('ru-dev-aya.csv', sep='\t', quoting=csv.QUOTE_NONE)

# %%
ari = adjusted_rand_score(train_new.sense_id, new_defs)
ari
# Out:
# 0.11673766924128653
